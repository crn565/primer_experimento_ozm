# %% [markdown]
# # Carga de datos capturados con el OZM

# %% [markdown]
# ## Primeros analisis de cargas de datos ¶
# En primer lugar, se analizan metadatos y datos del dataset cuya estructura deberia basarse en el formato NILMTK-DF.
#
# Contemos el numero de filas

# %%
import pandas as pd
df_datos_agregados = pd.read_hdf ('./data/kitchen_hood.hdf' )
print (len(df_datos_agregados.index))
# Out:
# 3000

# %% [markdown]
# Las primeras N filas del dataFrame se puede visualizar de la siguiente forma

# %%
N=4
df_datos_agregados.head(N)
# Out:
#             Time  Frequency  Unbalance   Flag  Voltage   Current  \
# 0  1613560157551    50.0077          0  False  224.966  0.787213
# 1  1613560157751    50.0077          0  False  224.936  0.788168
# 2  1613560157951    50.0077          0  False  224.948  0.787606
# 3  1613560158151    50.0077          0  False  224.991  0.788767
#
#    Active_Power  Reactive_Power  Power_Factor      Phi  \
# 0       106.752         138.901      0.602794 -52.4732
# 1       106.924         139.008      0.603111 -52.4487
# 2       106.553         139.079      0.601417 -52.5601
# 3       107.303         138.916      0.604641 -52.3303
#
#                            Voltage_Harmonics_Complex  \
# 0  [[1.1315, 224.902], [-0.222552, 0.079146], [-1...
# 1  [[2.34236, 224.863], [-0.228584, 0.085979], [-...
# 2  [[1.49234, 224.88], [-0.220408, -0.025378], [-...
# 3  [[0.794723, 224.928], [-0.213316, 0.065212], [...
#
#                            Current_Harmonics_Complex  \
# ...

# %% [markdown]
# Y las N últimas filas

# %%
df_datos_agregados.tail(N)
# Out:
#                Time  Frequency  Unbalance   Flag  Voltage  Current  \
# 2996  1613560756809    50.0090          0  False  223.938  1.75223
# 2997  1613560757009    50.0096          0  False  224.039  1.75372
# 2998  1613560757209    50.0096          0  False  224.120  1.75589
# 2999  1613560757409    50.0096          0  False  224.310  1.75882
#
#       Active_Power  Reactive_Power  Power_Factor      Phi  \
# 2996       211.902         325.058      0.540027 -56.9639
# 2997       212.450         325.217      0.540721 -56.9113
# 2998       212.954         325.692      0.541138 -56.8835
# 2999       213.426         326.515      0.540976 -56.8917
#
#                               Voltage_Harmonics_Complex  \
# 2996  [[-0.173252, 223.868], [-0.238601, 0.000895], ...
# 2997  [[1.01319, 223.965], [-0.246938, 0.115809], [-...
# 2998  [[2.56957, 224.037], [-0.246883, 0.034897], [-...
# 2999  [[1.89161, 224.233], [-0.24613, 0.008112], [-1...
#
# ...

# %% [markdown]
# Filtrar por un determinado valor

# %%
df_datos_agregados[df_datos_agregados.target =='kitchen_hood' ].head()
# Out:
#             Time  Frequency  Unbalance   Flag  Voltage   Current  \
# 0  1613560157551    50.0077          0  False  224.966  0.787213
# 1  1613560157751    50.0077          0  False  224.936  0.788168
# 2  1613560157951    50.0077          0  False  224.948  0.787606
# 3  1613560158151    50.0077          0  False  224.991  0.788767
# 4  1613560158351    50.0083          0  False  225.038  0.787594
#
#    Active_Power  Reactive_Power  Power_Factor      Phi  \
# 0       106.752         138.901      0.602794 -52.4732
# 1       106.924         139.008      0.603111 -52.4487
# 2       106.553         139.079      0.601417 -52.5601
# 3       107.303         138.916      0.604641 -52.3303
# 4       106.714         139.090      0.602094 -52.5187
#
#                            Voltage_Harmonics_Complex  \
# 0  [[1.1315, 224.902], [-0.222552, 0.079146], [-1...
# 1  [[2.34236, 224.863], [-0.228584, 0.085979], [-...
# 2  [[1.49234, 224.88], [-0.220408, -0.025378], [-...
# ...

# %% [markdown]
# Filtramos por un valor numerico

# %%
df_datos_agregados[df_datos_agregados.Frequency >=50 ].head()
# Out:
#             Time  Frequency  Unbalance   Flag  Voltage   Current  \
# 0  1613560157551    50.0077          0  False  224.966  0.787213
# 1  1613560157751    50.0077          0  False  224.936  0.788168
# 2  1613560157951    50.0077          0  False  224.948  0.787606
# 3  1613560158151    50.0077          0  False  224.991  0.788767
# 4  1613560158351    50.0083          0  False  225.038  0.787594
#
#    Active_Power  Reactive_Power  Power_Factor      Phi  \
# 0       106.752         138.901      0.602794 -52.4732
# 1       106.924         139.008      0.603111 -52.4487
# 2       106.553         139.079      0.601417 -52.5601
# 3       107.303         138.916      0.604641 -52.3303
# 4       106.714         139.090      0.602094 -52.5187
#
#                            Voltage_Harmonics_Complex  \
# 0  [[1.1315, 224.902], [-0.222552, 0.079146], [-1...
# 1  [[2.34236, 224.863], [-0.228584, 0.085979], [-...
# 2  [[1.49234, 224.88], [-0.220408, -0.025378], [-...
# ...

# %% [markdown]
# Añadir dos columnas mas

# %%
import numpy as np
import matplotlib.pyplot as plt
df_datos_agregados1=df_datos_agregados
df_datos_agregados1['x']=25*np.random.rand(len(df_datos_agregados))
df_datos_agregados1['y']=df_datos_agregados.Flag
df_datos_agregados1.head ()
# Out:
#             Time  Frequency  Unbalance   Flag  Voltage   Current  \
# 0  1613560157551    50.0077          0  False  224.966  0.787213
# 1  1613560157751    50.0077          0  False  224.936  0.788168
# 2  1613560157951    50.0077          0  False  224.948  0.787606
# 3  1613560158151    50.0077          0  False  224.991  0.788767
# 4  1613560158351    50.0083          0  False  225.038  0.787594
#
#    Active_Power  Reactive_Power  Power_Factor      Phi  \
# 0       106.752         138.901      0.602794 -52.4732
# 1       106.924         139.008      0.603111 -52.4487
# 2       106.553         139.079      0.601417 -52.5601
# 3       107.303         138.916      0.604641 -52.3303
# 4       106.714         139.090      0.602094 -52.5187
#
#                            Voltage_Harmonics_Complex  \
# 0  [[1.1315, 224.902], [-0.222552, 0.079146], [-1...
# 1  [[2.34236, 224.863], [-0.228584, 0.085979], [-...
# 2  [[1.49234, 224.88], [-0.220408, -0.025378], [-...
# ...

# %% [markdown]
# Obtener un dataset solo con determinadas columnas

# %%
import pandas as pd
df_datos_agregados = pd.read_hdf ('./data/kitchen_hood.hdf')
#df_datos_agregados [['Time','Frequency','Unbalance','Flag','Voltage','Current','Active_Power','Reactive_Power','Power_Factor','Phi','Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics','target']]
df_datos_agregados [['Voltage_Harmonics_Complex','Current_Harmonics_Complex']]
df_datos_agregados [['Voltage_Harmonics_Complex']].head(5)
#print(df_datos_agregados1)
# Out:
#                            Voltage_Harmonics_Complex
# 0  [[1.1315, 224.902], [-0.222552, 0.079146], [-1...
# 1  [[2.34236, 224.863], [-0.228584, 0.085979], [-...
# 2  [[1.49234, 224.88], [-0.220408, -0.025378], [-...
# 3  [[0.794723, 224.928], [-0.213316, 0.065212], [...
# 4  [[2.44248, 224.962], [-0.226191, 0.086812], [-...

# %% [markdown]
# Vamos a extrer todo el contenido por filas en grupos de 50

# %%
import pandas as pd
df_datos_agregados = pd.read_hdf ('./data/kitchen_hood.hdf',start=0, stop=50)
#print (len(df_datos_agregados.index))
df_datos_agregados
# Out:
#              Time  Frequency  Unbalance   Flag  Voltage   Current  \
# 0   1613560157551    50.0077          0  False  224.966  0.787213
# 1   1613560157751    50.0077          0  False  224.936  0.788168
# 2   1613560157951    50.0077          0  False  224.948  0.787606
# 3   1613560158151    50.0077          0  False  224.991  0.788767
# 4   1613560158351    50.0083          0  False  225.038  0.787594
# 5   1613560158551    50.0083          0  False  224.985  0.787759
# 6   1613560158751    50.0083          0  False  224.989  0.789214
# 7   1613560158951    50.0083          0  False  224.867  0.788988
# 8   1613560159151    50.0083          0  False  224.834  0.786053
# 9   1613560159351    50.0083          0  False  224.879  0.788720
# 10  1613560159551    50.0083          0  False  224.927  0.789856
# 11  1613560159751    50.0083          0  False  224.430  0.787188
# 12  1613560159951    50.0083          0  False  224.523  0.786935
# ...

# %% [markdown]
# Exportar contenido de fichero  hdf al formato csv

# %%
df_datos_agregados1 = pd.read_hdf ('./data/kitchen_hood.hdf')
df_datos_agregados1.to_csv('kitchen_hood.csv')

# %% [markdown]
# Exportar contenido de fichero hdf al formato xls

# %%
#df_datos_agregados1 = pd.read_hdf ('./data/kitchen_hood.hdf')
#df_datos_agregados1.to_excel('kitchen_hood.xlsx')
